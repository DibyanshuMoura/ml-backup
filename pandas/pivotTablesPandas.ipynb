# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Pivot Tables and Cross Tabs

# %% [markdown]
# ### Pivot Table

# %% [markdown]
# #### Used for Aggregation purpose

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    827     30   John  January      Q1
# 1  2023-01-02       B   West    954     92   Mary  January      Q1
# 2  2023-01-03       C  North    572     38    Bob  January      Q1
# 3  2023-01-04       D  South    982     25  Alice  January      Q1
# 4  2023-01-05       A   East    999     35   John  January      Q1
# 5  2023-01-06       B   West    153     75   Mary  January      Q1
# 6  2023-01-07       C  North    306     16    Bob  January      Q1
# 7  2023-01-08       D  South    885     64  Alice  January      Q1
# 8  2023-01-09       A   East    143     48   John  January      Q1
# 9  2023-01-10       B   West    100     40   Mary  January      Q1
# 10 2023-01-11       C  North    794     18    Bob  January      Q1
# 11 2023-01-12       D  South    914     44  Alice  January      Q1
# 12 2023-01-13       A   East    800     88   John  January      Q1
# 13 2023-01-14       B   West    177     99   Mary  January      Q1
# 14 2023-01-15       C  North    127     59    Bob  January      Q1
# 15 2023-01-16       D  South    201     55  Alice  January      Q1
# 16 2023-01-17       A   East    273     36   John  January      Q1
# 17 2023-01-18       B   West    674     18   Mary  January      Q1
# 18 2023-01-19       C  North    632     92    Bob  January      Q1
# 19 2023-01-20       D  South    131     29  Alice  January      Q1

# %%
pd.pivot_table(df,values = 'Sales',index = 'Region', columns = 'Product', aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     800.0    NaN    NaN    NaN
# North      NaN    NaN  572.0    NaN
# South      NaN    NaN    NaN  885.0
# West       NaN  177.0    NaN    NaN

# %%
pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     608.4    NaN    NaN    NaN  47.4   NaN   NaN   NaN
# North      NaN    NaN  486.2    NaN   NaN   NaN  44.6   NaN
# South      NaN    NaN    NaN  622.6   NaN   NaN   NaN  43.4
# West       NaN  411.6    NaN    NaN   NaN  64.8   NaN   NaN

# %% [markdown]
# ### Cross Tab

# %% [markdown]
# #### Used for Counting purpose

# %%
pd.crosstab(df['Region'], df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
