# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Dataframe is a combination of multiple Series.

# %% [markdown]
# Creation of dataframe

# %%
dataDict = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}

dfD = pd.DataFrame(dataDict)
dfD
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
dataList = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
dataCol = ['Name', 'Age', 'City', 'Salary']

dfL = pd.DataFrame(dataList, columns=dataCol)
dfL
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# Selection and idexing of Columns

# %%
dfL['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: str

# %%
dfL[['Name', 'City']]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# Creating a new column

# %%
dfL['Designation'] = ['HR', 'SDE', 'Engineer', 'Doctor']

# %%
dfL
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000          HR
# 1   Anna   34     Paris   70000         SDE
# 2  Peter   29    Berlin   62000    Engineer
# 3  Linda   42    London   85000      Doctor

# %% [markdown]
# Removing a column

# %%
dfL.drop('Designation', axis=1)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
dfL
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000          HR
# 1   Anna   34     Paris   70000         SDE
# 2  Peter   29    Berlin   62000    Engineer
# 3  Linda   42    London   85000      Doctor

# %%
dfL.drop('Designation', axis=1, inplace=True)

# %%
dfL
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
dfL.drop(['Age', 'Salary'], axis=1)
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %%
dfL
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
dfL.drop(0, axis=0)
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 2  Peter   29  Berlin   62000
# 3  Linda   42  London   85000

# %%
dfL
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# Selecting Rows

# %%
dfL
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
dfL.loc[0]
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
dfL['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: str

# %%
dfL.loc[[0, 1]]
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %% [markdown]
# Selecting subsets of rows and columns

# %%
dfL
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
dfL.loc[[0, 1], ['City', 'Salary']]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
dfL[['City', 'Salary']]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000
# 2    Berlin   62000
# 3    London   85000

# %%
dfL.loc[[2,3], ['Name', 'Age']]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# Conditional Selection

# %%
dfL
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# People with age above 30

# %%
dfL[dfL['Age'] > 30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %% [markdown]
# People with age above 30 and city must be paris

# %%
dfL[(dfL['Age'] > 30) & (dfL['City'] == "Paris")]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
